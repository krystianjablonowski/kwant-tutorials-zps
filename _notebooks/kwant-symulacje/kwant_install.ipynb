# %%
import os, sys
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
nb_path = '/content/notebooks'
os.remove(nb_path)
os.symlink('/content/drive/My Drive/Colab Notebooks', nb_path)
if nb_path not in sys.path:
  sys.path.insert(5, nb_path)
# Out:
# Mounted at /content/drive

# %%
# !pip install --target=$nb_path numpy
# !pip install --target=$nb_path kwant
# Out:
# Collecting numpy
#   Using cached numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
# Installing collected packages: numpy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0 requires tf-estimator-nightly==2.8.0.dev2021122109, which is not installed.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed numpy-1.21.6
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/shutil.py", line 566, in move
#     os.rename(src, real_dst)
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/pip-target-7zvkp2b5/lib/python/numpy-1.21.6.dist-info' -> '/content/notebooks/numpy-1.21.6.dist-info'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/cli/base_command.py", line 180, in _main
#     status = self.run(options, args)
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/cli/req_command.py", line 199, in wrapper
#     return func(self, options, args)
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/commands/install.py", line 450, in run
#     options.target_dir, target_temp_dir, options.upgrade
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/commands/install.py", line 509, in _handle_target_dir
#     target_item_dir
#   File "/usr/lib/python3.7/shutil.py", line 577, in move
#     symlinks=True)
#   File "/usr/lib/python3.7/shutil.py", line 324, in copytree
#     os.makedirs(dst)
#   File "/usr/lib/python3.7/os.py", line 223, in makedirs
#     mkdir(name, mode)
# FileNotFoundError: [Errno 2] No such file or directory: '/content/notebooks/numpy-1.21.6.dist-info'
# Collecting kwant
#   Using cached kwant-1.4.3-cp37-cp37m-linux_x86_64.whl
# Collecting numpy>=1.11.0
#   Using cached numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
# Collecting tinyarray>=1.2
#   Using cached tinyarray-1.2.4-cp37-cp37m-linux_x86_64.whl
# Collecting scipy>=0.17.0
#   Using cached scipy-1.7.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (38.1 MB)
# Installing collected packages: numpy, tinyarray, scipy, kwant
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0 requires tf-estimator-nightly==2.8.0.dev2021122109, which is not installed.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed kwant-1.4.3 numpy-1.21.6 scipy-1.7.3 tinyarray-1.2.4
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/shutil.py", line 566, in move
#     os.rename(src, real_dst)
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/pip-target-cbjn27uk/lib/python/numpy-1.21.6.dist-info' -> '/content/notebooks/numpy-1.21.6.dist-info'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/cli/base_command.py", line 180, in _main
#     status = self.run(options, args)
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/cli/req_command.py", line 199, in wrapper
#     return func(self, options, args)
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/commands/install.py", line 450, in run
#     options.target_dir, target_temp_dir, options.upgrade
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/commands/install.py", line 509, in _handle_target_dir
#     target_item_dir
#   File "/usr/lib/python3.7/shutil.py", line 577, in move
#     symlinks=True)
#   File "/usr/lib/python3.7/shutil.py", line 324, in copytree
#     os.makedirs(dst)
#   File "/usr/lib/python3.7/os.py", line 223, in makedirs
#     mkdir(name, mode)
# FileNotFoundError: [Errno 2] No such file or directory: '/content/notebooks/numpy-1.21.6.dist-info'
